# %%
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats, get_team_misc

# %%
get_team_stats("MIL", 2019, data_format='PER_GAME')
# Out:
# G              82
# MP          241.2
# FG           43.4
# FGA          91.1
# FG%         0.476
# 3P           13.5
# 3PA          38.2
# 3P%         0.353
# 2P           29.9
# 2PA          52.9
# 2P%         0.565
# FT           17.9
# FTA          23.2
# FT%         0.773
# ORB           9.3
# DRB          40.4
# TRB          49.7
# AST            26
# STL           7.5
# BLK           5.9
# TOV          13.9
# PF           19.6
# PTS         118.1
# TEAM          MIL
# SEASON    2018-19
# dtype: object

# %%
get_roster_stats("MIL", 2019, data_format='PER_GAME', playoffs=False)
# Out:
#                    PLAYER POS AGE TEAM   G  GS    MP    FG   FGA   FG%  ...  \
# 0   Giannis Antetokounmpo  PF  24  MIL  72  72  32.8  10.0  17.3  .578  ...
# 1            Eric Bledsoe  PG  29  MIL  78  78  29.1   6.0  12.4  .484  ...
# 2         Malcolm Brogdon  SG  26  MIL  64  64  28.6   5.9  11.7  .505  ...
# 3          Sterling Brown  SG  23  MIL  58   7  17.8   2.5   5.4  .465  ...
# 4           Isaiah Canaan  PG  27  MIL   4   0   7.8   0.5   1.5  .333  ...
# 5           Bonzie Colson  SF  23  MIL   8   2  12.3   1.6   4.9  .333  ...
# 6         Pat Connaughton  SG  26  MIL  61   2  20.7   2.7   5.7  .466  ...
# 7     Matthew Dellavedova  PG  28  MIL  12   0   8.1   0.5   1.6  .316  ...
# 8        Donte DiVincenzo  SG  22  MIL  27   0  15.2   1.9   4.6  .403  ...
# 9            Trevon Duval  PG  20  MIL   3   0   2.0   0.7   1.0  .667  ...
# 10            Tim Frazier  PG  28  MIL  12   2  17.6   2.3   5.5  .424  ...
# 11              Pau Gasol   C  38  MIL   3   0  10.0   0.3   2.0  .167  ...
# 12            John Henson   C  28  MIL  14   0  13.4   2.2   4.8  .463  ...
# 13            George Hill  PG  32  MIL  47   0  20.4   2.4   5.7  .428  ...
# 14        Ersan Ä°lyasova  PF  31  MIL  67   7  18.4   2.5   5.7  .438  ...
# 15            Brook Lopez   C  30  MIL  81  81  28.7   4.4   9.7  .452  ...
# 16             Thon Maker   C  21  MIL  35   0  11.7   1.7   3.8  .440  ...
# 17        Khris Middleton  SF  27  MIL  77  77  31.1   6.6  14.9  .441  ...
# 18        Nikola MirotiÄ‡  PF  27  MIL  14   3  22.9   4.0   9.6  .415  ...
# 19          Jaylen Morris  SG  23  MIL   4   0   7.3   1.0   2.5  .400  ...
# 20            Jason Smith  PF  32  MIL   6   0   6.7   0.7   2.2  .308  ...
# 21             Tony Snell  SF  27  MIL  74  12  17.6   2.2   4.9  .452  ...
# 22            D.J. Wilson  PF  22  MIL  48   3  18.4   2.2   5.2  .414  ...
# 23         Christian Wood  PF  23  MIL  13   0   4.8   0.9   1.9  .480  ...
#
#     ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS   SEASON
# 0   2.2  10.3  12.5  5.9  1.3  1.5  3.7  3.2  27.7  2018-19
# 1   1.1   3.6   4.6  5.5  1.5  0.4  2.1  2.0  15.9  2018-19
# 2   1.0   3.5   4.5  3.2  0.7  0.2  1.4  1.6  15.6  2018-19
# 3   0.5   2.7   3.2  1.4  0.4  0.1  0.8  1.5   6.4  2018-19
# 4   0.3   0.8   1.0  0.8  0.0  0.3  0.5  0.5   1.5  2018-19
# 5   1.0   2.8   3.8  0.4  0.6  0.1  0.4  0.4   4.9  2018-19
# 6   1.0   3.2   4.2  2.0  0.5  0.4  0.5  1.3   6.9  2018-19
# 7   0.0   0.8   0.8  2.4  0.2  0.0  0.9  0.8   1.7  2018-19
# 8   0.6   1.8   2.4  1.1  0.5  0.2  0.7  1.4   4.9  2018-19
# 9   0.0   0.3   0.3  0.7  0.0  0.0  0.0  0.0   1.7  2018-19
# 10  0.8   1.8   2.6  3.5  0.4  0.1  1.3  1.6   6.3  2018-19
# 11  0.0   3.3   3.3  0.7  0.0  0.3  0.7  0.3   1.3  2018-19
# 12  1.1   3.9   5.1  1.0  0.5  0.8  0.9  1.1   5.6  2018-19
# 13  0.6   2.0   2.6  2.1  0.9  0.1  0.7  1.4   6.8  2018-19
# 14  1.4   3.1   4.5  0.8  0.5  0.3  0.7  2.6   6.8  2018-19
# 15  0.4   4.5   4.9  1.2  0.6  2.2  1.0  2.3  12.5  2018-19
# 16  0.5   2.3   2.7  0.5  0.3  0.5  0.3  1.6   4.7  2018-19
# 17  0.6   5.3   6.0  4.3  1.0  0.1  2.3  2.2  18.3  2018-19
# 18  1.0   4.4   5.4  1.4  0.7  0.6  0.8  1.5  11.6  2018-19
# 19  0.0   1.3   1.3  1.0  0.5  0.0  0.3  0.3   2.5  2018-19
# 20  0.5   1.3   1.8  0.2  0.3  0.3  0.8  1.0   2.2  2018-19
# 21  0.4   1.7   2.1  0.9  0.4  0.2  0.3  1.2   6.0  2018-19
# 22  0.9   3.7   4.6  1.1  0.4  0.4  0.7  1.8   5.8  2018-19
# 23  0.3   1.2   1.5  0.2  0.0  0.0  0.2  0.2   2.8  2018-19
#
# [24 rows x 30 columns]
