# %%
import pandas
pandas.set_option('display.max_columns', None)
from nba import br_extractor

extractor = br_extractor.BRExtractor()

# %%
stats = extractor.get_player_stats(subset_by_seasons=[2020], subset_by_stat_types=["PER_GAME", "PER_100POSS"], subset_by_teams=["MIL"])
# Out:
# Retrieving per_game stats for season 2020 ...
# Retrieving per_100poss stats for season 2020 ...

# %%
stats.sample()
# Out:
#                            PLAYER POS AGE TEAM   G  GS MP_per_game  \
# player_season_team
# EricBledsoe_2020_MIL  EricBledsoe  PG  30  MIL  56  56        27.2
#
#                      FG_per_game FGA_per_game   FG% 3P_per_game 3PA_per_game  \
# player_season_team
# EricBledsoe_2020_MIL         5.7         11.8  .482         1.3          3.6
#
#                        3P% 2P_per_game 2PA_per_game   2P% EFG%_per_game  \
# player_season_team
# EricBledsoe_2020_MIL  .348         4.4          8.2  .540          .535
#
#                      FT_per_game FTA_per_game   FT% ORB_per_game DRB_per_game  \
# player_season_team
# EricBledsoe_2020_MIL         2.8          3.4  .813          0.7          3.9
#
#                      TRB_per_game AST_per_game STL_per_game BLK_per_game  \
# player_season_team
# EricBledsoe_2020_MIL          4.6          5.4          0.9          0.4
#
#                      TOV_per_game PF_per_game PTS_per_game SEASON  \
# player_season_team
# EricBledsoe_2020_MIL          2.5         2.1         15.4   2020
#
#                      MP_per_100poss FG_per_100poss FGA_per_100poss  \
# player_season_team
# EricBledsoe_2020_MIL           1524            9.6            19.9
#
#                      3P_per_100poss 3PA_per_100poss 2P_per_100poss  \
# player_season_team
# EricBledsoe_2020_MIL            2.1             6.0            7.5
#
#                      2PA_per_100poss FT_per_100poss FTA_per_100poss  \
# player_season_team
# EricBledsoe_2020_MIL            13.8            4.7             5.8
#
#                      FT.1_per_100poss ORB_per_100poss DRB_per_100poss  \
# player_season_team
# EricBledsoe_2020_MIL             .813             1.2             6.5
#
#                      TRB_per_100poss AST_per_100poss STL_per_100poss  \
# player_season_team
# EricBledsoe_2020_MIL             7.8             9.1             1.6
#
#                      BLK_per_100poss TOV_per_100poss PF_per_100poss  \
# player_season_team
# EricBledsoe_2020_MIL             0.7             4.2            3.6
#
#                      PTS_per_100poss ORTG_per_100poss DRTG_per_100poss
# player_season_team
# EricBledsoe_2020_MIL            25.9              113              103

# %%
stats.shape
# Out:
# (17, 51)

# %%
stats.sample(5)
# Out:
#                                    PLAYER POS AGE TEAM   G  GS MP_per_game  \
# player_season_team
# RobinLopez_2020_MIL            RobinLopez   C  31  MIL  60   4        14.4
# PatConnaughton_2020_MIL    PatConnaughton  SG  27  MIL  61   1        18.3
# DonteDiVincenzo_2020_MIL  DonteDiVincenzo  SG  23  MIL  59  22        23.1
# WesleyMatthews_2020_MIL    WesleyMatthews  SG  33  MIL  62  62        24.7
# BrookLopez_2020_MIL            BrookLopez   C  31  MIL  61  60        26.6
#
#                          FG_per_game FGA_per_game   FG% 3P_per_game  \
# player_season_team
# RobinLopez_2020_MIL              2.3          4.6  .502         0.6
# PatConnaughton_2020_MIL          2.0          4.3  .456         0.7
# DonteDiVincenzo_2020_MIL         3.5          7.7  .462         1.3
# WesleyMatthews_2020_MIL          2.6          6.5  .397         1.6
# BrookLopez_2020_MIL              4.0          9.4  .427         1.4
#
#                          3PA_per_game   3P% 2P_per_game 2PA_per_game   2P%  \
# player_season_team
# RobinLopez_2020_MIL               1.6  .344         1.7          3.0  .588
# PatConnaughton_2020_MIL           2.2  .321         1.2          2.0  .605
# DonteDiVincenzo_2020_MIL          3.7  .344         2.3          3.9  .576
# WesleyMatthews_2020_MIL           4.5  .365         0.9          2.0  .468
# BrookLopez_2020_MIL               4.7  .296         2.6          4.7  .557
#
#                          EFG%_per_game FT_per_game FTA_per_game   FT%  \
# player_season_team
# RobinLopez_2020_MIL               .562         0.4          0.7  .535
# PatConnaughton_2020_MIL           .540         0.4          0.6  .750
# DonteDiVincenzo_2020_MIL          .546         1.0          1.3  .769
# WesleyMatthews_2020_MIL           .522         0.8          1.0  .762
# BrookLopez_2020_MIL               .501         1.6          2.0  .810
#
#                          ORB_per_game DRB_per_game TRB_per_game AST_per_game  \
# player_season_team
# RobinLopez_2020_MIL               0.9          1.6          2.4          0.7
# PatConnaughton_2020_MIL           0.9          3.3          4.2          1.6
# DonteDiVincenzo_2020_MIL          1.0          3.9          4.9          2.3
# WesleyMatthews_2020_MIL           0.3          2.2          2.6          1.5
# BrookLopez_2020_MIL               0.7          3.8          4.5          1.6
#
#                          STL_per_game BLK_per_game TOV_per_game PF_per_game  \
# player_season_team
# RobinLopez_2020_MIL               0.2          0.7          0.9         1.3
# PatConnaughton_2020_MIL           0.3          0.5          0.8         1.0
# DonteDiVincenzo_2020_MIL          1.4          0.3          1.2         1.6
# WesleyMatthews_2020_MIL           0.6          0.1          0.7         1.5
# BrookLopez_2020_MIL               0.7          2.4          1.0         2.4
#
#                          PTS_per_game SEASON MP_per_100poss FG_per_100poss  \
# player_season_team
# RobinLopez_2020_MIL               5.5   2020            862            7.3
# PatConnaughton_2020_MIL           5.1   2020           1119            4.9
# DonteDiVincenzo_2020_MIL          9.4   2020           1362            7.0
# WesleyMatthews_2020_MIL           7.5   2020           1529            4.8
# BrookLopez_2020_MIL              11.0   2020           1622            6.9
#
#                          FGA_per_100poss 3P_per_100poss 3PA_per_100poss  \
# player_season_team
# RobinLopez_2020_MIL                 14.5            1.7             5.1
# PatConnaughton_2020_MIL             10.7            1.8             5.6
# DonteDiVincenzo_2020_MIL            15.2            2.6             7.4
# WesleyMatthews_2020_MIL             12.0            3.0             8.3
# BrookLopez_2020_MIL                 16.1            2.4             8.0
#
#                          2P_per_100poss 2PA_per_100poss FT_per_100poss  \
# player_season_team
# RobinLopez_2020_MIL                 5.5             9.4            1.2
# PatConnaughton_2020_MIL             3.1             5.1            1.1
# DonteDiVincenzo_2020_MIL            4.5             7.8            2.0
# WesleyMatthews_2020_MIL             1.7             3.7            1.4
# BrookLopez_2020_MIL                 4.5             8.1            2.8
#
#                          FTA_per_100poss FT.1_per_100poss ORB_per_100poss  \
# player_season_team
# RobinLopez_2020_MIL                  2.3             .535             2.8
# PatConnaughton_2020_MIL              1.5             .750             2.3
# DonteDiVincenzo_2020_MIL             2.6             .769             2.0
# WesleyMatthews_2020_MIL              1.9             .762             0.6
# BrookLopez_2020_MIL                  3.4             .810             1.2
#
#                          DRB_per_100poss TRB_per_100poss AST_per_100poss  \
# player_season_team
# RobinLopez_2020_MIL                  5.0             7.7             2.2
# PatConnaughton_2020_MIL              8.3            10.6             3.9
# DonteDiVincenzo_2020_MIL             7.7             9.7             4.6
# WesleyMatthews_2020_MIL              4.2             4.8             2.7
# BrookLopez_2020_MIL                  6.5             7.7             2.7
#
#                          STL_per_100poss BLK_per_100poss TOV_per_100poss  \
# player_season_team
# RobinLopez_2020_MIL                  0.5             2.2             2.9
# PatConnaughton_2020_MIL              0.8             1.2             1.9
# DonteDiVincenzo_2020_MIL             2.7             0.6             2.4
# WesleyMatthews_2020_MIL              1.1             0.3             1.2
# BrookLopez_2020_MIL                  1.2             4.2             1.8
#
#                          PF_per_100poss PTS_per_100poss ORTG_per_100poss  \
# player_season_team
# RobinLopez_2020_MIL                 4.2            17.5              104
# PatConnaughton_2020_MIL             2.5            12.6              113
# DonteDiVincenzo_2020_MIL            3.3            18.6              112
# WesleyMatthews_2020_MIL             2.7            14.0              109
# BrookLopez_2020_MIL                 4.1            18.9              106
#
#                          DRTG_per_100poss
# player_season_team
# RobinLopez_2020_MIL                   104
# PatConnaughton_2020_MIL               103
# DonteDiVincenzo_2020_MIL              100
# WesleyMatthews_2020_MIL               106
# BrookLopez_2020_MIL                    99
